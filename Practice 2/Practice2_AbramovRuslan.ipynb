# %% [markdown]
# # Практическая работа №2

# %% [markdown]
# ## Тема: «Предобработка данных в Pandas»

# %% [markdown]
# ### Выполнил студент: Абрамов Руслан Закирович

# %%
import pandas as pd

# %% [markdown]
# ### ВАРИАНТ: 1

# %% [markdown]
# ### Задание 1. Создать Series s1 и s2 по картинке

# %% [markdown]
# ![OWra1HbLZos.jpg](attachment:37984d52-324c-4837-a22b-6f4cee997209.jpg)

# %%
s1 = pd.DataFrame({'apples': [3,2,0,1]})
s1
# Out:
#    apples
# 0       3
# 1       2
# 2       0
# 3       1

# %%
s2 = pd.DataFrame({'oranges': [0,3,7,2]})
s2
# Out:
#    oranges
# 0        0
# 1        3
# 2        7
# 3        2

# %% [markdown]
# ### Задание 2. Создать DataFrame df1 по картинке

# %% [markdown]
# ![image.jpg](attachment:3acc6e1f-123e-4ce2-9b6e-be09339d13c0.jpg)

# %%
df1 = pd.DataFrame({'apples': [3,2,0,1],'oranges': [0,3,7,2]})
df1
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# ### Задание 3. Загрузить ваш DataSet

# %%
data = pd.read_csv('heart_disease.csv', sep=';', on_bad_lines='skip', low_memory=False)

# %% [markdown]
# ### Задание 4. Показать первые 10 записей вашего DataFrame

# %%
data.head(10)
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
# 5  Alabama    Male          Poor                 1.0               0.0
# 6  Alabama  Female     Very good                 0.0               0.0
# 7  Alabama  Female          Good                 0.0               0.0
# 8  Alabama  Female          Good                 0.0               0.0
# 9  Alabama  Female          Good                 1.0               0.0
#
#    PhysicalActivities  SleepHours RemovedTeeth HadHeartAttack HadAngina  ...  \
# 0                 0.0         8.0          NaN             No        No  ...
# 1                 0.0         6.0          NaN             No        No  ...
# 2                 1.0         5.0          NaN             No        No  ...
# 3                 1.0         7.0          NaN             No        No  ...
# 4                 1.0         9.0          NaN             No        No  ...
# 5                 0.0         7.0          NaN            Yes        No  ...
# 6                 1.0         7.0          NaN             No        No  ...
# 7                 0.0         8.0          NaN             No        No  ...
# 8                 1.0         6.0          NaN             No        No  ...
# 9                 1.0         7.0          NaN             No        No  ...
#
#   DifficultyDressingBathing DifficultyErrands  \
# 0                        No                No
# 1                        No                No
# 2                        No                No
# 3                        No                No
# 4                        No                No
# 5                        No                No
# 6                        No                No
# 7                        No                No
# 8                        No                No
# 9                        No                No
#
#                             SmokerStatus  \
# 0                           Never smoked
# 1                           Never smoked
# 2                           Never smoked
# 3  Current smoker - now smokes some days
# 4                           Never smoked
# 5                           Never smoked
# 6                          Former smoker
# 7                           Never smoked
# 8                          Former smoker
# 9                           Never smoked
#
#                              ECigaretteUsage ChestScan  \
# 0                     Not at all (right now)        No
# 1  Never used e-cigarettes in my entire life        No
# 2  Never used e-cigarettes in my entire life        No
# 3  Never used e-cigarettes in my entire life       Yes
# 4  Never used e-cigarettes in my entire life       Yes
# 5  Never used e-cigarettes in my entire life        No
# 6  Never used e-cigarettes in my entire life        No
# 7  Never used e-cigarettes in my entire life       Yes
# 8                     Not at all (right now)       NaN
# 9  Never used e-cigarettes in my entire life       NaN
#
#       RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0  White only, Non-Hispanic  Age 80 or older               NaN
# 1  White only, Non-Hispanic  Age 80 or older             68.04
# 2  White only, Non-Hispanic     Age 55 to 59              63.5
# 3  White only, Non-Hispanic              NaN              63.5
# 4  White only, Non-Hispanic     Age 40 to 44             53.98
# 5  White only, Non-Hispanic  Age 80 or older             84.82
# 6  Black only, Non-Hispanic  Age 80 or older              62.6
# 7  White only, Non-Hispanic  Age 80 or older             73.48
# 8  White only, Non-Hispanic     Age 75 to 79               NaN
# 9  White only, Non-Hispanic     Age 70 to 74             81.65
#
#   AlcoholDrinkers CovidPos
# 0              No       No
# 1              No       No
# 2              No      Yes
# 3              No       No
# 4             Yes       No
# 5              No       No
# 6             Yes       No
# 7              No       No
# 8              No       No
# 9             Yes       No
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Задание 5. Показать последние 10 записей вашего DataFrame

# %%
data.tail(10)
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 99988  Illinois  Female     Very good                 0.0               0.0
# 99989  Illinois  Female     Excellent                 0.0               7.0
# 99990  Illinois  Female          Good                 0.0               0.0
# 99991  Illinois  Female     Very good                 0.0               0.0
# 99992  Illinois  Female          Fair                29.0               0.0
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99995  Illinois  Female     Very good                 0.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 99988                 1.0         6.0  6 or more, but not all             No
# 99989                 1.0         7.0            None of them             No
# 99990                 1.0         7.0                  1 to 5             No
# 99991                 1.0         8.0  6 or more, but not all             No
# 99992                 0.0         6.0                  1 to 5            Yes
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99995                 0.0         7.0                  1 to 5             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 99988        No  ...                        No                No
# 99989        No  ...                        No                No
# 99990        No  ...                        No                No
# 99991        No  ...                        No                No
# 99992       Yes  ...                       Yes               Yes
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#         SmokerStatus                            ECigaretteUsage ChestScan  \
# 99988   Never smoked  Never used e-cigarettes in my entire life       Yes
# 99989  Former smoker  Never used e-cigarettes in my entire life        No
# 99990  Former smoker  Never used e-cigarettes in my entire life        No
# 99991  Former smoker  Never used e-cigarettes in my entire life        No
# 99992  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99993  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99994  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99995            NaN                                        NaN       NaN
# 99996  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99997  Former smoker  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 99988  Black only, Non-Hispanic  Age 80 or older             79.38
# 99989  Black only, Non-Hispanic     Age 55 to 59             72.57
# 99990  White only, Non-Hispanic     Age 70 to 74            122.92
# 99991  White only, Non-Hispanic     Age 70 to 74             113.4
# 99992  White only, Non-Hispanic  Age 80 or older             58.51
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 99988             Yes                                                 No
# 99989             Yes                                                Yes
# 99990             Yes                                                 No
# 99991             Yes                                                 No
# 99992             Yes                                                 No
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995             NaN                                                NaN
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Задание 6. Показать случайные 10 строк из вашего DataFrame

# %%
data.sample(10)
# Out:
#              State     Sex GeneralHealth  PhysicalHealthDays  \
# 87472       Hawaii    Male          Fair                 0.0
# 68328      Florida  Female          Fair                 0.0
# 69314      Florida  Female          Fair                 4.0
# 10977      Arizona    Male          Good                10.0
# 25367     Arkansas  Female     Very good                 1.0
# 16139      Arizona    Male     Very good                 0.0
# 55678  Connecticut    Male          Fair                 4.0
# 64887      Florida    Male     Excellent                 0.0
# 42071     Colorado    Male     Very good                 0.0
# 49492  Connecticut    Male          Fair                 0.0
#
#        MentalHealthDays  PhysicalActivities  SleepHours  RemovedTeeth  \
# 87472              30.0                 0.0         8.0        1 to 5
# 68328               3.0                 1.0         7.0        1 to 5
# 69314               2.0                 1.0         6.0  None of them
# 10977               1.0                 1.0         8.0  None of them
# 25367               2.0                 1.0         8.0  None of them
# 16139               0.0                 1.0         8.0  None of them
# 55678              30.0                 1.0        10.0  None of them
# 64887               0.0                 1.0         8.0  None of them
# 42071               0.0                 1.0         9.0        1 to 5
# 49492               0.0                 1.0         9.0           NaN
#
#       HadHeartAttack HadAngina  ... DifficultyDressingBathing  \
# 87472             No        No  ...                        No
# 68328             No        No  ...                        No
# 69314             No        No  ...                       NaN
# 10977             No        No  ...                        No
# 25367             No        No  ...                        No
# 16139             No        No  ...                        No
# 55678            NaN        No  ...                        No
# 64887             No        No  ...                        No
# 42071             No        No  ...                        No
# 49492             No        No  ...                        No
#
#       DifficultyErrands                           SmokerStatus  \
# 87472                No                          Former smoker
# 68328                No  Current smoker - now smokes every day
# 69314               NaN                                    NaN
# 10977                No                           Never smoked
# 25367                No                          Former smoker
# 16139                No                           Never smoked
# 55678                No  Current smoker - now smokes every day
# 64887                No                          Former smoker
# 42071                No  Current smoker - now smokes every day
# 49492                No                           Never smoked
#
#                                  ECigaretteUsage ChestScan  \
# 87472                         Use them some days        No
# 68328  Never used e-cigarettes in my entire life        No
# 69314                                        NaN       NaN
# 10977  Never used e-cigarettes in my entire life        No
# 25367                     Not at all (right now)        No
# 16139  Never used e-cigarettes in my entire life       Yes
# 55678                     Not at all (right now)       Yes
# 64887  Never used e-cigarettes in my entire life        No
# 42071  Never used e-cigarettes in my entire life       Yes
# 49492                     Not at all (right now)       Yes
#
#                RaceEthnicityCategory   AgeCategory WeightInKilograms  \
# 87472  Other race only, Non-Hispanic  Age 50 to 54             95.25
# 68328       White only, Non-Hispanic  Age 30 to 34             93.44
# 69314       White only, Non-Hispanic  Age 60 to 64               NaN
# 10977  Other race only, Non-Hispanic  Age 65 to 69             73.03
# 25367       White only, Non-Hispanic  Age 30 to 34             74.84
# 16139       White only, Non-Hispanic  Age 45 to 49            108.86
# 55678                       Hispanic  Age 40 to 44            149.23
# 64887                       Hispanic  Age 50 to 54             90.72
# 42071       White only, Non-Hispanic  Age 55 to 59             68.04
# 49492                       Hispanic  Age 65 to 69             72.57
#
#       AlcoholDrinkers CovidPos
# 87472              No       No
# 68328             Yes       No
# 69314             NaN      NaN
# 10977             Yes       No
# 25367             Yes      Yes
# 16139             Yes       No
# 55678              No      Yes
# 64887             Yes      Yes
# 42071             Yes       No
# 49492              No       No
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Задание 7. Показать типы данных для каждого столбца в DataFrame

# %%
data.dtypes
# Out:
# State                         object
# Sex                           object
# GeneralHealth                 object
# PhysicalHealthDays           float64
# MentalHealthDays             float64
# PhysicalActivities           float64
# SleepHours                   float64
# RemovedTeeth                  object
# HadHeartAttack                object
# HadAngina                     object
# HadStroke                     object
# HadAsthma                     object
# HadSkinCancer                 object
# HadCOPD                       object
# HadDepressiveDisorder         object
# HadKidneyDisease              object
# HadArthritis                  object
# HadDiabetes                   object
# DeafOrHardOfHearing           object
# BlindOrVisionDifficulty       object
# DifficultyConcentrating       object
# DifficultyWalking             object
# DifficultyDressingBathing     object
# DifficultyErrands             object
# SmokerStatus                  object
# ECigaretteUsage               object
# ChestScan                     object
# RaceEthnicityCategory         object
# AgeCategory                   object
# WeightInKilograms             object
# AlcoholDrinkers               object
# CovidPos                      object
# dtype: object

# %% [markdown]
# ### Задание 8. Показать информацию о DataFrame, включая количество непропущенных значений, типы данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99998 entries, 0 to 99997
# Data columns (total 32 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      99998 non-null  object
#  1   Sex                        99998 non-null  object
#  2   GeneralHealth              99716 non-null  object
#  3   PhysicalHealthDays         97332 non-null  float64
#  4   MentalHealthDays           97784 non-null  float64
#  5   PhysicalActivities         99735 non-null  float64
#  6   SleepHours                 98779 non-null  float64
#  7   RemovedTeeth               96407 non-null  object
#  8   HadHeartAttack             99214 non-null  object
#  9   HadAngina                  98955 non-null  object
#  10  HadStroke                  99607 non-null  object
#  11  HadAsthma                  99565 non-null  object
#  12  HadSkinCancer              99196 non-null  object
#  13  HadCOPD                    99469 non-null  object
#  14  HadDepressiveDisorder      99334 non-null  object
#  15  HadKidneyDisease           99545 non-null  object
#  16  HadArthritis               99403 non-null  object
#  17  HadDiabetes                99703 non-null  object
#  18  DeafOrHardOfHearing        94829 non-null  object
#  19  BlindOrVisionDifficulty    94563 non-null  object
#  20  DifficultyConcentrating    93911 non-null  object
#  21  DifficultyWalking          93860 non-null  object
#  22  DifficultyDressingBathing  93864 non-null  object
#  23  DifficultyErrands          93457 non-null  object
#  24  SmokerStatus               90983 non-null  object
#  25  ECigaretteUsage            90865 non-null  object
#  26  ChestScan                  86487 non-null  object
#  27  RaceEthnicityCategory      96494 non-null  object
#  28  AgeCategory                97770 non-null  object
#  29  WeightInKilograms          90464 non-null  object
#  30  AlcoholDrinkers            88382 non-null  object
#  31  CovidPos                   87136 non-null  object
# dtypes: float64(4), object(28)
# memory usage: 24.4+ MB

# %% [markdown]
# ### Задание 9. Показать статистический анализ числовых столбцов, включая среднее, стандартное отклонение, минимум и максимум о DataFrame

# %%
data.describe()
# Out:
#        PhysicalHealthDays  MentalHealthDays  PhysicalActivities    SleepHours
# count        97332.000000      97784.000000        99735.000000  98779.000000
# mean             4.436650          4.406815            0.765398      7.015327
# std              8.770373          8.417985            0.423752      1.526573
# min              0.000000          0.000000            0.000000      1.000000
# 25%              0.000000          0.000000            1.000000      6.000000
# 50%              0.000000          0.000000            1.000000      7.000000
# 75%              4.000000          5.000000            1.000000      8.000000
# max             30.000000         30.000000            1.000000     24.000000

# %% [markdown]
# ### Задание 10. Показать Возвращает DataFrame с булевыми значениями, указывающими на пропущенные значения

# %%
data.isna()
# Out:
#        State    Sex  GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0      False  False          False               False             False
# 1      False  False          False               False             False
# 2      False  False          False               False             False
# 3      False  False          False               False             False
# 4      False  False          False               False             False
# ...      ...    ...            ...                 ...               ...
# 99993  False  False          False               False             False
# 99994  False  False          False               False             False
# 99995  False  False          False               False             False
# 99996  False  False          False               False             False
# 99997  False  False          False               False             False
#
#        PhysicalActivities  SleepHours  RemovedTeeth  HadHeartAttack  \
# 0                   False       False          True           False
# 1                   False       False          True           False
# 2                   False       False          True           False
# 3                   False       False          True           False
# 4                   False       False          True           False
# ...                   ...         ...           ...             ...
# 99993               False       False         False           False
# 99994               False       False         False           False
# 99995               False       False         False           False
# 99996               False       False         False           False
# 99997               False       False         False           False
#
#        HadAngina  ...  DifficultyDressingBathing  DifficultyErrands  \
# 0          False  ...                      False              False
# 1          False  ...                      False              False
# 2          False  ...                      False              False
# 3          False  ...                      False              False
# 4          False  ...                      False              False
# ...          ...  ...                        ...                ...
# 99993      False  ...                      False              False
# 99994      False  ...                      False              False
# 99995      False  ...                      False              False
# 99996      False  ...                      False              False
# 99997      False  ...                      False              False
#
#        SmokerStatus  ECigaretteUsage  ChestScan  RaceEthnicityCategory  \
# 0             False            False      False                  False
# 1             False            False      False                  False
# 2             False            False      False                  False
# 3             False            False      False                  False
# 4             False            False      False                  False
# ...             ...              ...        ...                    ...
# 99993         False            False      False                  False
# 99994         False            False      False                  False
# 99995          True             True       True                  False
# 99996         False            False      False                  False
# 99997         False            False      False                  False
#
#        AgeCategory  WeightInKilograms  AlcoholDrinkers  CovidPos
# 0            False               True            False     False
# 1            False              False            False     False
# 2            False              False            False     False
# 3             True              False            False     False
# 4            False              False            False     False
# ...            ...                ...              ...       ...
# 99993        False              False            False     False
# 99994        False              False            False     False
# 99995        False              False             True      True
# 99996        False              False            False     False
# 99997        False              False            False     False
#
# [99998 rows x 32 columns]

# %% [markdown]
# ### Задание 11. Заменить пропущенные значения значением value в DataFrame

# %%
data.fillna('value')
# Out:
#           State     Sex GeneralHealth PhysicalHealthDays MentalHealthDays  \
# 0       Alabama  Female     Very good                0.0              0.0
# 1       Alabama  Female     Excellent                0.0              0.0
# 2       Alabama  Female     Very good                2.0              3.0
# 3       Alabama  Female     Excellent                0.0              0.0
# 4       Alabama  Female          Fair                2.0              0.0
# ...         ...     ...           ...                ...              ...
# 99993  Illinois  Female          Poor               30.0             30.0
# 99994  Illinois    Male     Very good               14.0              0.0
# 99995  Illinois  Female     Very good                0.0              0.0
# 99996  Illinois  Female     Very good                0.0              0.0
# 99997  Illinois  Female          Good                0.0              3.0
#
#       PhysicalActivities SleepHours            RemovedTeeth HadHeartAttack  \
# 0                    0.0        8.0                   value             No
# 1                    0.0        6.0                   value             No
# 2                    1.0        5.0                   value             No
# 3                    1.0        7.0                   value             No
# 4                    1.0        9.0                   value             No
# ...                  ...        ...                     ...            ...
# 99993                1.0        6.0                  1 to 5             No
# 99994                0.0        8.0            None of them             No
# 99995                0.0        7.0                  1 to 5             No
# 99996                1.0        6.0                  1 to 5             No
# 99997                1.0        8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 0            No  ...                        No                No
# 1            No  ...                        No                No
# 2            No  ...                        No                No
# 3            No  ...                        No                No
# 4            No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#                                 SmokerStatus  \
# 0                               Never smoked
# 1                               Never smoked
# 2                               Never smoked
# 3      Current smoker - now smokes some days
# 4                               Never smoked
# ...                                      ...
# 99993                          Former smoker
# 99994                          Former smoker
# 99995                                  value
# 99996                          Former smoker
# 99997                          Former smoker
#
#                                  ECigaretteUsage ChestScan  \
# 0                         Not at all (right now)        No
# 1      Never used e-cigarettes in my entire life        No
# 2      Never used e-cigarettes in my entire life        No
# 3      Never used e-cigarettes in my entire life       Yes
# 4      Never used e-cigarettes in my entire life       Yes
# ...                                          ...       ...
# 99993  Never used e-cigarettes in my entire life       Yes
# 99994  Never used e-cigarettes in my entire life       Yes
# 99995                                      value     value
# 99996  Never used e-cigarettes in my entire life       Yes
# 99997  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0      White only, Non-Hispanic  Age 80 or older             value
# 1      White only, Non-Hispanic  Age 80 or older             68.04
# 2      White only, Non-Hispanic     Age 55 to 59              63.5
# 3      White only, Non-Hispanic            value              63.5
# 4      White only, Non-Hispanic     Age 40 to 44             53.98
# ...                         ...              ...               ...
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 0                  No                                                 No
# 1                  No                                                 No
# 2                  No                                                Yes
# 3                  No                                                 No
# 4                 Yes                                                 No
# ...               ...                                                ...
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995           value                                              value
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [99998 rows x 32 columns]

# %% [markdown]
# ### Задание 12. Заменить пропущенные значения значением среднего в DataFrame

# %% [markdown]
# ### data.fillna(data.mean())

# %%
data[data.columns[3:7]].mean()
# Out:
# PhysicalHealthDays    4.436650
# MentalHealthDays      4.406815
# PhysicalActivities    0.765398
# SleepHours            7.015327
# dtype: float64

# %%
data.fillna(data[data.columns[6]].mean())
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Alabama  Female     Very good                 0.0               0.0
# 1       Alabama  Female     Excellent                 0.0               0.0
# 2       Alabama  Female     Very good                 2.0               3.0
# 3       Alabama  Female     Excellent                 0.0               0.0
# 4       Alabama  Female          Fair                 2.0               0.0
# ...         ...     ...           ...                 ...               ...
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99995  Illinois  Female     Very good                 0.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 0                     0.0         8.0                7.015327             No
# 1                     0.0         6.0                7.015327             No
# 2                     1.0         5.0                7.015327             No
# 3                     1.0         7.0                7.015327             No
# 4                     1.0         9.0                7.015327             No
# ...                   ...         ...                     ...            ...
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99995                 0.0         7.0                  1 to 5             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 0            No  ...                        No                No
# 1            No  ...                        No                No
# 2            No  ...                        No                No
# 3            No  ...                        No                No
# 4            No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#                                 SmokerStatus  \
# 0                               Never smoked
# 1                               Never smoked
# 2                               Never smoked
# 3      Current smoker - now smokes some days
# 4                               Never smoked
# ...                                      ...
# 99993                          Former smoker
# 99994                          Former smoker
# 99995                               7.015327
# 99996                          Former smoker
# 99997                          Former smoker
#
#                                  ECigaretteUsage ChestScan  \
# 0                         Not at all (right now)        No
# 1      Never used e-cigarettes in my entire life        No
# 2      Never used e-cigarettes in my entire life        No
# 3      Never used e-cigarettes in my entire life       Yes
# 4      Never used e-cigarettes in my entire life       Yes
# ...                                          ...       ...
# 99993  Never used e-cigarettes in my entire life       Yes
# 99994  Never used e-cigarettes in my entire life       Yes
# 99995                                   7.015327  7.015327
# 99996  Never used e-cigarettes in my entire life       Yes
# 99997  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0      White only, Non-Hispanic  Age 80 or older          7.015327
# 1      White only, Non-Hispanic  Age 80 or older             68.04
# 2      White only, Non-Hispanic     Age 55 to 59              63.5
# 3      White only, Non-Hispanic         7.015327              63.5
# 4      White only, Non-Hispanic     Age 40 to 44             53.98
# ...                         ...              ...               ...
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 0                  No                                                 No
# 1                  No                                                 No
# 2                  No                                                Yes
# 3                  No                                                 No
# 4                 Yes                                                 No
# ...               ...                                                ...
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995        7.015327                                           7.015327
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [99998 rows x 32 columns]

# %% [markdown]
# ### Задание 13. Заменить пропущенные значения значением медианны в DataFrame

# %% [markdown]
# ### data.fillna(data.median())

# %%
data[data.columns[3:7]].median()
# Out:
# PhysicalHealthDays    0.0
# MentalHealthDays      0.0
# PhysicalActivities    1.0
# SleepHours            7.0
# dtype: float64

# %%
data.fillna(data[data.columns[3:6]].max())
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Alabama  Female     Very good                 0.0               0.0
# 1       Alabama  Female     Excellent                 0.0               0.0
# 2       Alabama  Female     Very good                 2.0               3.0
# 3       Alabama  Female     Excellent                 0.0               0.0
# 4       Alabama  Female          Fair                 2.0               0.0
# ...         ...     ...           ...                 ...               ...
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99995  Illinois  Female     Very good                 0.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 0                     0.0         8.0                     NaN             No
# 1                     0.0         6.0                     NaN             No
# 2                     1.0         5.0                     NaN             No
# 3                     1.0         7.0                     NaN             No
# 4                     1.0         9.0                     NaN             No
# ...                   ...         ...                     ...            ...
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99995                 0.0         7.0                  1 to 5             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 0            No  ...                        No                No
# 1            No  ...                        No                No
# 2            No  ...                        No                No
# 3            No  ...                        No                No
# 4            No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#                                 SmokerStatus  \
# 0                               Never smoked
# 1                               Never smoked
# 2                               Never smoked
# 3      Current smoker - now smokes some days
# 4                               Never smoked
# ...                                      ...
# 99993                          Former smoker
# 99994                          Former smoker
# 99995                                    NaN
# 99996                          Former smoker
# 99997                          Former smoker
#
#                                  ECigaretteUsage ChestScan  \
# 0                         Not at all (right now)        No
# 1      Never used e-cigarettes in my entire life        No
# 2      Never used e-cigarettes in my entire life        No
# 3      Never used e-cigarettes in my entire life       Yes
# 4      Never used e-cigarettes in my entire life       Yes
# ...                                          ...       ...
# 99993  Never used e-cigarettes in my entire life       Yes
# 99994  Never used e-cigarettes in my entire life       Yes
# 99995                                        NaN       NaN
# 99996  Never used e-cigarettes in my entire life       Yes
# 99997  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0      White only, Non-Hispanic  Age 80 or older               NaN
# 1      White only, Non-Hispanic  Age 80 or older             68.04
# 2      White only, Non-Hispanic     Age 55 to 59              63.5
# 3      White only, Non-Hispanic              NaN              63.5
# 4      White only, Non-Hispanic     Age 40 to 44             53.98
# ...                         ...              ...               ...
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 0                  No                                                 No
# 1                  No                                                 No
# 2                  No                                                Yes
# 3                  No                                                 No
# 4                 Yes                                                 No
# ...               ...                                                ...
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995             NaN                                                NaN
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [99998 rows x 32 columns]

# %% [markdown]
# ### Задание 14. Заменить пропущенные значения значением максимальным в DataFrame

# %% [markdown]
# ### data.fillna(data.max())

# %%
data[data.columns[3:7]].max()
# Out:
# PhysicalHealthDays    30.0
# MentalHealthDays      30.0
# PhysicalActivities     1.0
# SleepHours            24.0
# dtype: float64

# %%
data.fillna(data[data.columns[3]].max())
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Alabama  Female     Very good                 0.0               0.0
# 1       Alabama  Female     Excellent                 0.0               0.0
# 2       Alabama  Female     Very good                 2.0               3.0
# 3       Alabama  Female     Excellent                 0.0               0.0
# 4       Alabama  Female          Fair                 2.0               0.0
# ...         ...     ...           ...                 ...               ...
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99995  Illinois  Female     Very good                 0.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 0                     0.0         8.0                    30.0             No
# 1                     0.0         6.0                    30.0             No
# 2                     1.0         5.0                    30.0             No
# 3                     1.0         7.0                    30.0             No
# 4                     1.0         9.0                    30.0             No
# ...                   ...         ...                     ...            ...
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99995                 0.0         7.0                  1 to 5             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 0            No  ...                        No                No
# 1            No  ...                        No                No
# 2            No  ...                        No                No
# 3            No  ...                        No                No
# 4            No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#                                 SmokerStatus  \
# 0                               Never smoked
# 1                               Never smoked
# 2                               Never smoked
# 3      Current smoker - now smokes some days
# 4                               Never smoked
# ...                                      ...
# 99993                          Former smoker
# 99994                          Former smoker
# 99995                                   30.0
# 99996                          Former smoker
# 99997                          Former smoker
#
#                                  ECigaretteUsage ChestScan  \
# 0                         Not at all (right now)        No
# 1      Never used e-cigarettes in my entire life        No
# 2      Never used e-cigarettes in my entire life        No
# 3      Never used e-cigarettes in my entire life       Yes
# 4      Never used e-cigarettes in my entire life       Yes
# ...                                          ...       ...
# 99993  Never used e-cigarettes in my entire life       Yes
# 99994  Never used e-cigarettes in my entire life       Yes
# 99995                                       30.0      30.0
# 99996  Never used e-cigarettes in my entire life       Yes
# 99997  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0      White only, Non-Hispanic  Age 80 or older              30.0
# 1      White only, Non-Hispanic  Age 80 or older             68.04
# 2      White only, Non-Hispanic     Age 55 to 59              63.5
# 3      White only, Non-Hispanic             30.0              63.5
# 4      White only, Non-Hispanic     Age 40 to 44             53.98
# ...                         ...              ...               ...
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 0                  No                                                 No
# 1                  No                                                 No
# 2                  No                                                Yes
# 3                  No                                                 No
# 4                 Yes                                                 No
# ...               ...                                                ...
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995            30.0                                               30.0
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [99998 rows x 32 columns]

# %% [markdown]
# ### Задание 15. Заменить пропущенные значения значением минимальным в DataFrame

# %% [markdown]
# ### data.fillna(data.min())

# %%
data[data.columns[3:7]].min()
# Out:
# PhysicalHealthDays    0.0
# MentalHealthDays      0.0
# PhysicalActivities    0.0
# SleepHours            1.0
# dtype: float64

# %%
data.fillna(data[data.columns[6]].min())
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Alabama  Female     Very good                 0.0               0.0
# 1       Alabama  Female     Excellent                 0.0               0.0
# 2       Alabama  Female     Very good                 2.0               3.0
# 3       Alabama  Female     Excellent                 0.0               0.0
# 4       Alabama  Female          Fair                 2.0               0.0
# ...         ...     ...           ...                 ...               ...
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99995  Illinois  Female     Very good                 0.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 0                     0.0         8.0                     1.0             No
# 1                     0.0         6.0                     1.0             No
# 2                     1.0         5.0                     1.0             No
# 3                     1.0         7.0                     1.0             No
# 4                     1.0         9.0                     1.0             No
# ...                   ...         ...                     ...            ...
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99995                 0.0         7.0                  1 to 5             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 0            No  ...                        No                No
# 1            No  ...                        No                No
# 2            No  ...                        No                No
# 3            No  ...                        No                No
# 4            No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#                                 SmokerStatus  \
# 0                               Never smoked
# 1                               Never smoked
# 2                               Never smoked
# 3      Current smoker - now smokes some days
# 4                               Never smoked
# ...                                      ...
# 99993                          Former smoker
# 99994                          Former smoker
# 99995                                    1.0
# 99996                          Former smoker
# 99997                          Former smoker
#
#                                  ECigaretteUsage ChestScan  \
# 0                         Not at all (right now)        No
# 1      Never used e-cigarettes in my entire life        No
# 2      Never used e-cigarettes in my entire life        No
# 3      Never used e-cigarettes in my entire life       Yes
# 4      Never used e-cigarettes in my entire life       Yes
# ...                                          ...       ...
# 99993  Never used e-cigarettes in my entire life       Yes
# 99994  Never used e-cigarettes in my entire life       Yes
# 99995                                        1.0       1.0
# 99996  Never used e-cigarettes in my entire life       Yes
# 99997  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0      White only, Non-Hispanic  Age 80 or older               1.0
# 1      White only, Non-Hispanic  Age 80 or older             68.04
# 2      White only, Non-Hispanic     Age 55 to 59              63.5
# 3      White only, Non-Hispanic              1.0              63.5
# 4      White only, Non-Hispanic     Age 40 to 44             53.98
# ...                         ...              ...               ...
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 0                  No                                                 No
# 1                  No                                                 No
# 2                  No                                                Yes
# 3                  No                                                 No
# 4                 Yes                                                 No
# ...               ...                                                ...
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995             1.0                                                1.0
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [99998 rows x 32 columns]

# %% [markdown]
# ### Задание 16. Показать количество уникальных значений в каждом столбце в DataFrame

# %%
data.nunique()
# Out:
# State                         14
# Sex                            2
# GeneralHealth                  5
# PhysicalHealthDays            31
# MentalHealthDays              31
# PhysicalActivities             2
# SleepHours                    24
# RemovedTeeth                   4
# HadHeartAttack                 2
# HadAngina                      2
# HadStroke                      2
# HadAsthma                      2
# HadSkinCancer                  2
# HadCOPD                        2
# HadDepressiveDisorder          2
# HadKidneyDisease               2
# HadArthritis                   2
# HadDiabetes                    4
# DeafOrHardOfHearing            2
# BlindOrVisionDifficulty        2
# DifficultyConcentrating        2
# DifficultyWalking              2
# DifficultyDressingBathing      2
# DifficultyErrands              2
# SmokerStatus                   4
# ECigaretteUsage                4
# ChestScan                      2
# RaceEthnicityCategory          5
# AgeCategory                   13
# WeightInKilograms            471
# AlcoholDrinkers                2
# CovidPos                       3
# dtype: int64

# %% [markdown]
# ### Задание 17. Подсчитать количество вхождений каждого уникального значения в столбце в DataFrame

# %% [markdown]
# ### data.value_counts()

# %%
data.value_counts(data.columns[2])
# Out:
# GeneralHealth
# Very good    32743
# Good         31970
# Excellent    16960
# Fair         13394
# Poor          4649
# Name: count, dtype: int64

# %% [markdown]
# ### Задание 18. Удалить строки с пропущенными значениями в DataFrame

# %%
data.dropna()
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 342     Alabama  Female     Very good                 4.0               0.0
# 343     Alabama    Male     Very good                 0.0               0.0
# 345     Alabama    Male     Very good                 0.0               0.0
# 346     Alabama  Female          Fair                 5.0               0.0
# 347     Alabama  Female          Good                 3.0              15.0
# ...         ...     ...           ...                 ...               ...
# 99992  Illinois  Female          Fair                29.0               0.0
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 342                   1.0         9.0            None of them             No
# 343                   1.0         6.0            None of them             No
# 345                   0.0         8.0  6 or more, but not all             No
# 346                   1.0         9.0            None of them             No
# 347                   1.0         5.0                  1 to 5             No
# ...                   ...         ...                     ...            ...
# 99992                 0.0         6.0                  1 to 5            Yes
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 342          No  ...                        No                No
# 343          No  ...                        No                No
# 345          No  ...                        No                No
# 346          No  ...                        No                No
# 347          No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99992       Yes  ...                       Yes               Yes
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#         SmokerStatus                            ECigaretteUsage ChestScan  \
# 342    Former smoker  Never used e-cigarettes in my entire life        No
# 343    Former smoker  Never used e-cigarettes in my entire life        No
# 345    Former smoker  Never used e-cigarettes in my entire life       Yes
# 346     Never smoked  Never used e-cigarettes in my entire life        No
# 347     Never smoked  Never used e-cigarettes in my entire life        No
# ...              ...                                        ...       ...
# 99992  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99993  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99994  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99996  Former smoker  Never used e-cigarettes in my entire life       Yes
# 99997  Former smoker  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 342    White only, Non-Hispanic     Age 65 to 69             71.67
# 343    White only, Non-Hispanic     Age 70 to 74             95.25
# 345    White only, Non-Hispanic     Age 75 to 79            108.86
# 346    White only, Non-Hispanic  Age 80 or older             90.72
# 347    White only, Non-Hispanic  Age 80 or older             79.38
# ...                         ...              ...               ...
# 99992  White only, Non-Hispanic  Age 80 or older             58.51
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 342                No                                                 No
# 343                No                                                 No
# 345               Yes                                                Yes
# 346                No                                                Yes
# 347                No                                                 No
# ...               ...                                                ...
# 99992             Yes                                                 No
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [67085 rows x 32 columns]

# %% [markdown]
# ### Задание 19. Показать булевы значения, указывающие на дубликаты строк в DataFrame

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99993    False
# 99994    False
# 99995    False
# 99996    False
# 99997    False
# Length: 99998, dtype: bool

# %% [markdown]
# ### Задание 20. Удалить дубликаты строк из DataFrame

# %%
data.drop_duplicates()
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Alabama  Female     Very good                 0.0               0.0
# 1       Alabama  Female     Excellent                 0.0               0.0
# 2       Alabama  Female     Very good                 2.0               3.0
# 3       Alabama  Female     Excellent                 0.0               0.0
# 4       Alabama  Female          Fair                 2.0               0.0
# ...         ...     ...           ...                 ...               ...
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99995  Illinois  Female     Very good                 0.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 0                     0.0         8.0                     NaN             No
# 1                     0.0         6.0                     NaN             No
# 2                     1.0         5.0                     NaN             No
# 3                     1.0         7.0                     NaN             No
# 4                     1.0         9.0                     NaN             No
# ...                   ...         ...                     ...            ...
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99995                 0.0         7.0                  1 to 5             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 0            No  ...                        No                No
# 1            No  ...                        No                No
# 2            No  ...                        No                No
# 3            No  ...                        No                No
# 4            No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#                                 SmokerStatus  \
# 0                               Never smoked
# 1                               Never smoked
# 2                               Never smoked
# 3      Current smoker - now smokes some days
# 4                               Never smoked
# ...                                      ...
# 99993                          Former smoker
# 99994                          Former smoker
# 99995                                    NaN
# 99996                          Former smoker
# 99997                          Former smoker
#
#                                  ECigaretteUsage ChestScan  \
# 0                         Not at all (right now)        No
# 1      Never used e-cigarettes in my entire life        No
# 2      Never used e-cigarettes in my entire life        No
# 3      Never used e-cigarettes in my entire life       Yes
# 4      Never used e-cigarettes in my entire life       Yes
# ...                                          ...       ...
# 99993  Never used e-cigarettes in my entire life       Yes
# 99994  Never used e-cigarettes in my entire life       Yes
# 99995                                        NaN       NaN
# 99996  Never used e-cigarettes in my entire life       Yes
# 99997  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0      White only, Non-Hispanic  Age 80 or older               NaN
# 1      White only, Non-Hispanic  Age 80 or older             68.04
# 2      White only, Non-Hispanic     Age 55 to 59              63.5
# 3      White only, Non-Hispanic              NaN              63.5
# 4      White only, Non-Hispanic     Age 40 to 44             53.98
# ...                         ...              ...               ...
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 0                  No                                                 No
# 1                  No                                                 No
# 2                  No                                                Yes
# 3                  No                                                 No
# 4                 Yes                                                 No
# ...               ...                                                ...
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995             NaN                                                NaN
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [99909 rows x 32 columns]

# %% [markdown]
# ### Задание 21. Заменить определенное значения в DataFrame на указанные значения

# %%
data.replace('Excellent', 'Превосходно')
# Out:
#           State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0       Alabama  Female     Very good                 0.0               0.0
# 1       Alabama  Female   Превосходно                 0.0               0.0
# 2       Alabama  Female     Very good                 2.0               3.0
# 3       Alabama  Female   Превосходно                 0.0               0.0
# 4       Alabama  Female          Fair                 2.0               0.0
# ...         ...     ...           ...                 ...               ...
# 99993  Illinois  Female          Poor                30.0              30.0
# 99994  Illinois    Male     Very good                14.0               0.0
# 99995  Illinois  Female     Very good                 0.0               0.0
# 99996  Illinois  Female     Very good                 0.0               0.0
# 99997  Illinois  Female          Good                 0.0               3.0
#
#        PhysicalActivities  SleepHours            RemovedTeeth HadHeartAttack  \
# 0                     0.0         8.0                     NaN             No
# 1                     0.0         6.0                     NaN             No
# 2                     1.0         5.0                     NaN             No
# 3                     1.0         7.0                     NaN             No
# 4                     1.0         9.0                     NaN             No
# ...                   ...         ...                     ...            ...
# 99993                 1.0         6.0                  1 to 5             No
# 99994                 0.0         8.0            None of them             No
# 99995                 0.0         7.0                  1 to 5             No
# 99996                 1.0         6.0                  1 to 5             No
# 99997                 1.0         8.0  6 or more, but not all             No
#
#       HadAngina  ... DifficultyDressingBathing DifficultyErrands  \
# 0            No  ...                        No                No
# 1            No  ...                        No                No
# 2            No  ...                        No                No
# 3            No  ...                        No                No
# 4            No  ...                        No                No
# ...         ...  ...                       ...               ...
# 99993       Yes  ...                        No                No
# 99994        No  ...                        No                No
# 99995        No  ...                        No                No
# 99996        No  ...                        No                No
# 99997        No  ...                        No                No
#
#                                 SmokerStatus  \
# 0                               Never smoked
# 1                               Never smoked
# 2                               Never smoked
# 3      Current smoker - now smokes some days
# 4                               Never smoked
# ...                                      ...
# 99993                          Former smoker
# 99994                          Former smoker
# 99995                                    NaN
# 99996                          Former smoker
# 99997                          Former smoker
#
#                                  ECigaretteUsage ChestScan  \
# 0                         Not at all (right now)        No
# 1      Never used e-cigarettes in my entire life        No
# 2      Never used e-cigarettes in my entire life        No
# 3      Never used e-cigarettes in my entire life       Yes
# 4      Never used e-cigarettes in my entire life       Yes
# ...                                          ...       ...
# 99993  Never used e-cigarettes in my entire life       Yes
# 99994  Never used e-cigarettes in my entire life       Yes
# 99995                                        NaN       NaN
# 99996  Never used e-cigarettes in my entire life       Yes
# 99997  Never used e-cigarettes in my entire life       Yes
#
#           RaceEthnicityCategory      AgeCategory WeightInKilograms  \
# 0      White only, Non-Hispanic  Age 80 or older               NaN
# 1      White only, Non-Hispanic  Age 80 or older             68.04
# 2      White only, Non-Hispanic     Age 55 to 59              63.5
# 3      White only, Non-Hispanic              NaN              63.5
# 4      White only, Non-Hispanic     Age 40 to 44             53.98
# ...                         ...              ...               ...
# 99993  White only, Non-Hispanic     Age 75 to 79             88.45
# 99994  White only, Non-Hispanic     Age 65 to 69             78.47
# 99995  Black only, Non-Hispanic     Age 75 to 79             77.11
# 99996  Black only, Non-Hispanic     Age 70 to 74             52.16
# 99997  White only, Non-Hispanic  Age 80 or older             60.33
#
#       AlcoholDrinkers                                           CovidPos
# 0                  No                                                 No
# 1                  No                                                 No
# 2                  No                                                Yes
# 3                  No                                                 No
# 4                 Yes                                                 No
# ...               ...                                                ...
# 99993              No                                                 No
# 99994             Yes  Tested positive using home test without a heal...
# 99995             NaN                                                NaN
# 99996             Yes                                                Yes
# 99997             Yes  Tested positive using home test without a heal...
#
# [99998 rows x 32 columns]

# %% [markdown]
# ### Задание 22. Сохранить DataFrame в формат Excel с именем Practice2_dataset.xlsx

# %%
data.to_excel('Practice2_dataset.xlsx')

# %% [markdown]
# ### Задание 23. Сохранить DataFrame в формат CSV с именем Practice2_dataset.CSV

# %%
data.to_csv('Practice2_dataset.csv')

# %% [markdown]
# ### Задание 24. Сохранить DataFrame в формат JSON с именем Practice2_ dataset.json

# %%
data.to_json('Practice2_dataset.json')
